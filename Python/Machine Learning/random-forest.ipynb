# %%
# Formação Cientista de Dados - Fernando Amaral e Jones Granatyr
# Algoritmo Random Forest
# Importação das bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Carregamento da base de dados e criação dos previsores (variáveis independentes - X) e da classe (variável dependente - y)
credito = pd.read_csv('Credit.csv')
credito.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = credito.iloc[:,0:20].values
classe = credito.iloc[:,20].values

# %%
# Transformação dos atributos categóricos em atributos numéricos, passando o índice de cada atributo categórico
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:, 3] = labelencoder.fit_transform(previsores[:, 3])
previsores[:, 5] = labelencoder.fit_transform(previsores[:, 5])
previsores[:, 6] = labelencoder.fit_transform(previsores[:, 6])
previsores[:, 8] = labelencoder.fit_transform(previsores[:, 8])
previsores[:, 9] = labelencoder.fit_transform(previsores[:, 9])
previsores[:, 11] = labelencoder.fit_transform(previsores[:, 11])
previsores[:, 13] = labelencoder.fit_transform(previsores[:, 13])
previsores[:, 14] = labelencoder.fit_transform(previsores[:, 14])
previsores[:, 16] = labelencoder.fit_transform(previsores[:, 16])
previsores[:, 18] = labelencoder.fit_transform(previsores[:, 18])
previsores[:, 19] = labelencoder.fit_transform(previsores[:, 19])

# %%
# Divisão da base de dados entre treinamento e teste (30% para testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(previsores,
                                                                  classe,
                                                                  test_size = 0.3,
                                                                  random_state = 0)

# %%
# Criação do modelo, treinamento, obtenção das previsões e da taxa de acerto
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier()

# %%
# Visualização dos atributos principais
floresta.estimators_
#floresta.estimators_[1]
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1878464358),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1341899405),
#  DecisionTreeClassifier(max_features='sqrt', random_state=687907766),
#  DecisionTreeClassifier(max_features='sqrt', random_state=100709983),
#  DecisionTreeClassifier(max_features='sqrt', random_state=957222480),
#  DecisionTreeClassifier(max_features='sqrt', random_state=794568678),
#  DecisionTreeClassifier(max_features='sqrt', random_state=652510935),
#  DecisionTreeClassifier(max_features='sqrt', random_state=598623032),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2049490870),
#  DecisionTreeClassifier(max_features='sqrt', random_state=326228441),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1158625399),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1569894584),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1197426698),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1051973073),
#  DecisionTreeClassifier(max_features='sqrt', random_state=448056496),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2126526275),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1161953335),
#  DecisionTreeClassifier(max_features='sqrt', random_state=485546843),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1066123846),
#  DecisionTreeClassifier(max_features='sqrt', random_state=268025805),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2019890002),
#  DecisionTreeClassifier(max_features='sqrt', random_state=24350359),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2026562052),
#  DecisionTreeClassifier(max_features='sqrt', random_state=476658837),
#  DecisionTreeClassifier(max_features='sqrt', random_state=534950047),
#  DecisionTreeClassifier(max_features='sqrt', random_state=22900947),
#  DecisionTreeClassifier(max_features='sqrt', random_state=766580236),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1239891141),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1483184585),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1194283399),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2089876205),
#  DecisionTreeClassifier(max_features='sqrt', random_state=506784592),
#  DecisionTreeClassifier(max_features='sqrt', random_state=281676536),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1968633371),
#  DecisionTreeClassifier(max_features='sqrt', random_state=656887860),
#  DecisionTreeClassifier(max_features='sqrt', random_state=743277673),
#  DecisionTreeClassifier(max_features='sqrt', random_state=192219507),
#  DecisionTreeClassifier(max_features='sqrt', random_state=285280265),
#  DecisionTreeClassifier(max_features='sqrt', random_state=526668790),
#  DecisionTreeClassifier(max_features='sqrt', random_state=318461850),
#  DecisionTreeClassifier(max_features='sqrt', random_state=424913572),
#  DecisionTreeClassifier(max_features='sqrt', random_state=44867505),
#  DecisionTreeClassifier(max_features='sqrt', random_state=425965171),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1180916965),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1867684523),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1180765041),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1924163567),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1013980924),
#  DecisionTreeClassifier(max_features='sqrt', random_state=889913572),
#  DecisionTreeClassifier(max_features='sqrt', random_state=866187940),
#  DecisionTreeClassifier(max_features='sqrt', random_state=643975109),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1017579641),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1243428443),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1238025368),
#  DecisionTreeClassifier(max_features='sqrt', random_state=25921530),
#  DecisionTreeClassifier(max_features='sqrt', random_state=896886109),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1226823392),
#  DecisionTreeClassifier(max_features='sqrt', random_state=75216084),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1843017072),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1454772072),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1566389784),
#  DecisionTreeClassifier(max_features='sqrt', random_state=73578937),
#  DecisionTreeClassifier(max_features='sqrt', random_state=793914223),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1072864987),
#  DecisionTreeClassifier(max_features='sqrt', random_state=808445058),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1983312602),
#  DecisionTreeClassifier(max_features='sqrt', random_state=579161518),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1015243003),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1355593706),
#  DecisionTreeClassifier(max_features='sqrt', random_state=589102480),
#  DecisionTreeClassifier(max_features='sqrt', random_state=972701588),
#  DecisionTreeClassifier(max_features='sqrt', random_state=459378802),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1788960400),
#  DecisionTreeClassifier(max_features='sqrt', random_state=389605964),
#  DecisionTreeClassifier(max_features='sqrt', random_state=58052352),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2143382172),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2056072651),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2019451606),
#  DecisionTreeClassifier(max_features='sqrt', random_state=585548016),
#  DecisionTreeClassifier(max_features='sqrt', random_state=457859101),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1048938992),
#  DecisionTreeClassifier(max_features='sqrt', random_state=161861342),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1171196189),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1146905579),
#  DecisionTreeClassifier(max_features='sqrt', random_state=990723049),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1075634646),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1695718460),
#  DecisionTreeClassifier(max_features='sqrt', random_state=153785976),
#  DecisionTreeClassifier(max_features='sqrt', random_state=376803553),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1520960320),
#  DecisionTreeClassifier(max_features='sqrt', random_state=357042233),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1633520090),
#  DecisionTreeClassifier(max_features='sqrt', random_state=985020466),
#  DecisionTreeClassifier(max_features='sqrt', random_state=28892027),
#  DecisionTreeClassifier(max_features='sqrt', random_state=258707088),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1333460416),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1485816456),
#  DecisionTreeClassifier(max_features='sqrt', random_state=710499617),
#  DecisionTreeClassifier(max_features='sqrt', random_state=539013532),
#  DecisionTreeClassifier(max_features='sqrt', random_state=757723364)]

# %%
previsoes = floresta.predict(X_teste)
confusao = confusion_matrix(y_teste, previsoes)
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.7866666666666666
